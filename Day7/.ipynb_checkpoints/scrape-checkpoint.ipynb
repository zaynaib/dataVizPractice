# %%
from splinter import Browser
import time
import requests
from PIL import Image
import os
import csv
import io
import hashlib
#browser = Browser('chrome', executable_path, headless=False)

# %%
executable_path = {'executable_path': 'chromedriver.exe'}

# %%
def scroll_to_end(driver,sleep_interactions):
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(sleep_interactions)

        #selenium.time.sleep(sleep_between_interactions)

# %%
def fetch_images(path, query,s_interactions,max_links_to_fetch):

    #open chrome driver
    wd = Browser('chrome', path, headless=False) # defaults to firefox

    #create query string
    search_url = "https://www.google.com/search?safe=off&site=&tbm=isch&source=hp&q={q}&oq={q}&gs_l=img"
    
    #search for the query
    wd.visit(search_url.format(q=query))

    
    #parameter set up
    image_urls = []
    image_count = 0
    results_start = 0

    while image_count < max_links_to_fetch:
        #scroll_to_end(wd,s_interactions)

        # get all image thumbnail results
        thumbnail_results = wd.find_by_css("img.Q4LuWd")
        number_results = len(thumbnail_results)
        image_count += 1
        
        print(f"Found: {number_results} search results. Extracting links from {results_start}:{number_results}")
        print(image_count)

        for img in thumbnail_results[results_start:max_links_to_fetch]:
            # try to click every thumbnail such that we can get the real image behind it
            try:
                img.click()
                time.sleep(s_interactions)
            except Exception:
                #wd.quit()
                continue

            # extract image urls    
            actual_images = wd.find_by_css('img.n3VNCb')
            for actual_image in actual_images:
                if actual_image['src'] and 'http' in actual_image['src']:
                    image_urls.append(actual_image['src'])

    #         image_count = len(image_urls)

            if len(image_urls) >= max_links_to_fetch:
                print(f"Found: {len(image_urls)}, {query} image links, done!")
                break
        else:
            print("Found:", len(image_urls), "image links, looking for more ...")
            wd.quit()
            time.sleep(3)
            

        # move the result startpoint further down
        #results_start = len(thumbnail_results)
        wd.quit()

    return image_urls

# %%
fetch_images(executable_path,"Dogs",60,1)
# Out:
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Dogs image links, done!
# ['https://i.ytimg.com/vi/MPV2METPeJU/maxresdefault.jpg']

# %%
def persist_image(folder_path,url,img_name):
    try:
        image_content = requests.get(url).content

    except Exception as e:
        print(f"ERROR - Could not download {url} - {e}")

    try:
        image_file = io.BytesIO(image_content)
        image = Image.open(image_file).convert('RGB')

        picture_path = img_name.replace(" ", "-").lower()
        #print(picture_path)

        #file_path = os.path.join(folder_path,picture_path + '.jpg')
        #file_path = os.path.join(folder_path,img_name + '.jpg')


        if img_name is None:
            file_path = os.path.join(folder_path,hashlib.sha1(image_content).hexdigest()[:10] + '.jpg')
            print(img_name)
        else:
            file_path = os.path.join(folder_path,picture_path + '.jpg')
        with open(file_path, 'wb') as f:
            image.save(f, "JPEG", quality=85)
        print(f"SUCCESS - saved {url} - as {file_path}")
    except Exception as e:
        print(f"ERROR - Could not save {url} - {e}")

# %%
persist_image("./test", "https://upload.wikimedia.org/wikipedia/commons/thumb/c/c1/21_Savage_2018.jpg/1200px-21_Savage_2018.jpg","21_savage")
# Out:
# ERROR - Could not save https://upload.wikimedia.org/wikipedia/commons/thumb/c/c1/21_Savage_2018.jpg/1200px-21_Savage_2018.jpg - [Errno 2] No such file or directory: './test\\21_savage.jpg'

# %%
file_path = os.path.join("hiphop2.csv")
rapper_urls= []
dummy_image = "https://upload.wikimedia.org/wikipedia/en/thumb/a/a6/Pok%C3%A9mon_Pikachu_art.png/220px-Pok%C3%A9mon_Pikachu_art.png"
#rappers_not_found = []
with open(file_path) as rapper_data:
    reader = csv.reader(rapper_data)
    #header = next(reader)

    #read a specific row
    reader_list = list(reader)

    for row in reader_list[92:]:
        #print(row[3])
        rapper_name = row[4] 
        rapper_search = f'{row[4]} rapper' 
        rapper_url = fetch_images(executable_path,rapper_name,3,1)
        #print(rapper_url)
        try:
            rapper_urls.append({"url":rapper_url[0],"name":rapper_name})
            #persist_image("./assets/images",rapper_url[0],rapper_name)

        except Exception as e:
            print(e)
            rapper_urls.append(dummy_image)
            rappers_not_found.append(rapper_name)



#print(rapper_urls)
# Out:
# Found: 48 search results. Extracting links from 0:48
# 1
# Found: 1, Lil' Kim image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Lil Uzi Vert image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Lil Wayne image links, done!
# Found: 48 search results. Extracting links from 0:48
# 1
# Found: 1, Lil Yachty image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, LL Cool J image links, done!
# Found: 48 search results. Extracting links from 0:48
# 1
# Found: 1, Logic image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Ludacris image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Lupe Fiasco image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Mac Miller image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Mac Dre image links, done!
# Found: 48 search results. Extracting links from 0:48
# 1
# Found: 1, Machine Gun Kelly image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Master P image links, done!
# Found: 48 search results. Extracting links from 0:48
# 1
# Found: 1, MC Lyte image links, done!
# Found: 48 search results. Extracting links from 0:48
# 1
# Found: 0 image links, looking for more ...
# list index out of range
# Found: 48 search results. Extracting links from 0:48
# 1
# Found: 1, Method Man image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, MF DOOM image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 0 image links, looking for more ...
# list index out of range
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Missy Elliot image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Mobb Deep image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Mos Def image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Murs image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Nas image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Nelly image links, done!
# Found: 50 search results. Extracting links from 0:50
# 1
# Found: 0 image links, looking for more ...
# list index out of range
# Found: 48 search results. Extracting links from 0:48
# 1
# Found: 1, Nicki Minaj image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Outkast image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Petey Pablo image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Public Enemy image links, done!
# Found: 48 search results. Extracting links from 0:48
# 1
# Found: 1, Puff Daddy image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Raekwon image links, done!
# Found: 48 search results. Extracting links from 0:48
# 1
# Found: 1, Rakim image links, done!
# Found: 48 search results. Extracting links from 0:48
# 1
# Found: 1, Redman image links, done!
# Found: 48 search results. Extracting links from 0:48
# 1
# Found: 1, Rich Homie Quan image links, done!
# Found: 48 search results. Extracting links from 0:48
# 1
# Found: 1, Rich the Kid image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 0 image links, looking for more ...
# list index out of range
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Rittz image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, The Roots image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Royce da 5'9 image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Run-D.M.C. image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Russ image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, RZA image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Sage Francis image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Salt-n-Pepa image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Scarface image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 0 image links, looking for more ...
# list index out of range
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Skyzoo image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Snoop Dogg image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 0 image links, looking for more ...
# list index out of range
# Found: 50 search results. Extracting links from 0:50
# 1
# Found: 1, T.I. image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Talib Kweli image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Tech n9ne image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Three 6 Mafia image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Too Short image links, done!
# Found: 48 search results. Extracting links from 0:48
# 1
# Found: 1, Travis Scott image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, A Tribe Called Quest image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Trick Daddy image links, done!
# Found: 48 search results. Extracting links from 0:48
# 1
# Found: 1, Trina image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Twista image links, done!
# Found: 48 search results. Extracting links from 0:48
# 1
# Found: 1, Tyga image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Tyler the Creator image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, UGK image links, done!
# Found: 48 search results. Extracting links from 0:48
# 1
# Found: 1, Vince Staples image links, done!
# Found: 48 search results. Extracting links from 0:48
# 1
# Found: 1, Wale image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Watsky image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Wiz Khalifa image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 0 image links, looking for more ...
# list index out of range
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Xzibit image links, done!
# Found: 50 search results. Extracting links from 0:50
# 1
# Found: 1, YG image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, YoungBoy Never Broke Again image links, done!
# Found: 49 search results. Extracting links from 0:49
# 1
# Found: 1, Young Jeezy image links, done!
# Found: 48 search results. Extracting links from 0:48
# 1
# Found: 1, Young Thug image links, done!

# %%
len(rapper_urls)
# Out:
# 85

# %%
rappers_not_found
# Out:
# ['Big Daddy Kane',
#  'Big Daddy Kane',
#  'GZA',
#  'Killah Priest',
#  'KRS-One',
#  'Meek Mill',
#  'Migos',
#  'NF',
#  'Rick Ross',
#  'ScHoolboy Q',
#  '$uicideboy$',
#  'Wu-Tang Clan']

# %%
for rapper in rapper_urls:
    try:
        persist_image("./assets/images",rapper['url'],rapper['name'])

    except Exception as e:
        print(e)
# Out:
# SUCCESS - saved https://observer.com/wp-content/uploads/sites/2/2018/06/gettyimages-847158018.jpg?quality=80 - as ./assets/images\lil'-kim.jpg
# SUCCESS - saved https://www.rollingstone.com/wp-content/uploads/2021/02/lil-uzi-vert-diamond.jpg - as ./assets/images\lil-uzi-vert.jpg
# SUCCESS - saved https://i.guim.co.uk/img/media/282ad68589d12c94a9439aad73181466d75c54eb/0_150_3600_2160/master/3600.jpg?width=1200&height=1200&quality=85&auto=format&fit=crop&s=c8e2be5dd59936e726bdeb8e5acf1b13 - as ./assets/images\lil-wayne.jpg
# SUCCESS - saved https://upload.wikimedia.org/wikipedia/commons/5/5e/Lil_Yachty_cropped.jpg - as ./assets/images\lil-yachty.jpg
# SUCCESS - saved https://upload.wikimedia.org/wikipedia/commons/6/67/LL_Cool_J_in_2017.jpg - as ./assets/images\ll-cool-j.jpg
# SUCCESS - saved https://upload.wikimedia.org/wikipedia/commons/f/f0/Logic_Grandoozy_2018_%2845208197292%29.jpg - as ./assets/images\logic.jpg
# SUCCESS - saved https://upload.wikimedia.org/wikipedia/commons/c/c2/Ludacris_2008.jpg - as ./assets/images\ludacris.jpg
# SUCCESS - saved https://images.squarespace-cdn.com/content/v1/5df7b577f9fe4115214abed3/1579495025165-9R03TZXA4V4NOOF5X3VM/ke17ZwdGBToddI8pDm48kA9cKYRdOojqZhNuotuxuEFZw-zPPgdn4jUwVcJE1ZvWQUxwkmyExglNqGp0IvTJZUJFbgE-7XRK3dMEBRBhUpyC6P6v6b_Cdxm465Ca6K91bsO9cRUksJJ3D_YevAz6WBXsewf5A1G2g3RryXRn9rw/lupe-fiasco-home-header-2.png - as ./assets/images\lupe-fiasco.jpg
# SUCCESS - saved https://www.rollingstone.com/wp-content/uploads/2018/11/mac-miller-left-behind.jpg - as ./assets/images\mac-miller.jpg
# SUCCESS - saved https://static.wikia.nocookie.net/hip-hop-music/images/b/b8/Mac_Dre.jpg/revision/latest/scale-to-width-down/340?cb=20141004211453 - as ./assets/images\mac-dre.jpg
# SUCCESS - saved https://pagesix.com/wp-content/uploads/sites/3/2020/08/machine-gun-kelly-megan-fox.jpg?quality=80&strip=all - as ./assets/images\machine-gun-kelly.jpg
# SUCCESS - saved https://upload.wikimedia.org/wikipedia/commons/3/31/Master_p-02.jpg - as ./assets/images\master-p.jpg
# SUCCESS - saved https://upload.wikimedia.org/wikipedia/commons/8/81/MC_Lyte_by_Gage_Skidmore.jpg - as ./assets/images\mc-lyte.jpg
# string indices must be integers
# SUCCESS - saved https://upload.wikimedia.org/wikipedia/commons/thumb/a/a5/Method_Man_at_Shattuck_Down_Low.jpg/1200px-Method_Man_at_Shattuck_Down_Low.jpg - as ./assets/images\method-man.jpg
# SUCCESS - saved https://upload.wikimedia.org/wikipedia/commons